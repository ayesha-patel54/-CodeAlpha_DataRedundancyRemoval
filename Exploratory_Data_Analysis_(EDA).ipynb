# %% [markdown]
# <a href="https://colab.research.google.com/github/ayesha-patel54/-CodeAlpha_DataRedundancyRemoval/blob/main/Exploratory_Data_Analysis_(EDA).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {
    "OrderDate": ["2024-01-01", "2024-01-02", "2024-01-03", "2024-01-04", "2024-01-05"],
    "Product": ["Laptop", "Phone", "Tablet", "Laptop", "Phone"],
    "Quantity": [2, 5, 3, 1, 4],
    "Price": [50000, 20000, 15000, 50000, 20000]
}

df = pd.DataFrame(data)
df["TotalAmount"] = df["Quantity"] * df["Price"]

df.to_csv("sales_data.csv", index=False)

df.head()
# Out:
#     OrderDate Product  Quantity  Price  TotalAmount
# 0  2024-01-01  Laptop         2  50000       100000
# 1  2024-01-02   Phone         5  20000       100000
# 2  2024-01-03  Tablet         3  15000        45000
# 3  2024-01-04  Laptop         1  50000        50000
# 4  2024-01-05   Phone         4  20000        80000

# %%
df.describe()
# Out:
#        Quantity         Price    TotalAmount
# count  5.000000      5.000000       5.000000
# mean   3.000000  31000.000000   75000.000000
# std    1.581139  17464.249197   26457.513111
# min    1.000000  15000.000000   45000.000000
# 25%    2.000000  20000.000000   50000.000000
# 50%    3.000000  20000.000000   80000.000000
# 75%    4.000000  50000.000000  100000.000000
# max    5.000000  50000.000000  100000.000000

# %%
import matplotlib.pyplot as plt

df.groupby("Product")["TotalAmount"].sum().plot(kind="bar")
plt.title("Total Sales by Product")
plt.xlabel("Product")
plt.ylabel("Total Sales")
plt.show()

# %%
df["OrderDate"] = pd.to_datetime(df["OrderDate"])

df.groupby("OrderDate")["TotalAmount"].sum().plot(kind="line")
plt.title("Sales Trend Over Time")
plt.xlabel("Date")
plt.ylabel("Total Sales")
plt.show()
